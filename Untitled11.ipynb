# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/git-demo/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=str(input("enter your name: "))
age=int(input("enter your age: "))
city=str(input("enter your city: "))
print(f"your name is {name} and your age is {age} and your city is {city}" )
# Out:
# enter your name: gauri
# enter your age: 25
# enter your city: mathura
# your name is gauri and your age is 25 and your city is mathura
