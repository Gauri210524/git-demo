# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/git-demo/blob/main/Copy_of_Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="gauri shankar"
age=26
print("NAME:",(name),'AND','AGE:',(age))
# Out:
# NAME: gauri shankar AND AGE: 26
