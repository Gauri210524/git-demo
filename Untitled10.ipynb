# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/git-demo/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
NAME="aditi"
MARKS=98
CITY="delhi"
print(f"""
----STUDENT ID CARD----
    NAME : {NAME}
    MARKS : {MARKS}
    CITY : {CITY}
----------------------
      """)
# Out:
# ----STUDENT ID CARD----
#     NAME : aditi
#     MARKS : 98
#     CITY : delhi
# ----------------------
